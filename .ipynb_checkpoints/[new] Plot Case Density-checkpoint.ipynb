# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point, LineString
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
# %matplotlib inline

# %%
# read the illinois state shp data
illinois_shp = gpd.read_file('raw_il_census_tracts_shapefile/tl_2019_17_tract.shp')
# read the case information
ct_info_cases_df = pd.read_csv('Statistical_Analysis/data/ct_info_cases_data.csv')
ct_info_cases_df['GEOID'] = ct_info_cases_df['GEOID'].astype(str)

# %%
case_density_list = ['estimate_cases1_density', 'estimate_cases2_density', 'estimate_cases3_density', 'estimate_cases4_density']
for case_density in case_density_list:
    lower = np.quantile(ct_info_cases_df[case_density], 0.01)
    upper = np.quantile(ct_info_cases_df[case_density], 0.99)
    # print(lower, upper)
    # ct_info_cases_df[ct_info_cases_df[case_density] < lower] = lower   
    # ct_info_cases_df[ct_info_cases_df[case_density] > upper] = upper
    print(max(ct_info_cases_df['estimate_cases2_density']))

# for case_density in case_density_list:
#     ct_info_cases_df[case_density] = ct_info_cases_df[case_density]/np.max(
# Out:
# 2696.37503845541
# 2696.37503845541
# 2696.37503845541
# 2696.37503845541

# %%
# info_case_gdf = pd.merge(illinois_shp, ct_info_cases_df, how='left', on="GEOID")

# %%
np.max(ct_info_cases_df[case_density_list])
np.max(ct_info_cases_df['estimate_cases2_density'])
# Out:
# 2696.37503845541

# %%
# print(np.quantile(ct_info_cases_df['estimate_cases1_density'],0.99))
# print(np.quantile(ct_info_cases_df['estimate_cases2_density'],0.99))

print(np.max(ct_info_cases_df['estimate_cases1_density']))
print(np.max(ct_info_cases_df['estimate_cases2_density']))
print(np.max(ct_info_cases_df['estimate_cases3_density']))
print(np.max(ct_info_cases_df['estimate_cases4_density']))
# Out:
# 1002.9803866022743
# 1002.9803866022743
# 1002.9803866022743
# 1002.9803866022743

# %%
info_case_gdf['estimate_cases1_density']
# Out:
# 0       0.032914
# 1       0.033480
# 2       0.009239
# 3       0.005577
# 4       0.000000
#           ...
# 3118    0.000000
# 3119    0.000000
# 3120    0.000000
# 3121    0.000000
# 3122    0.000000
# Name: estimate_cases1_density, Length: 3123, dtype: float64

# %%
np.quantile(info_case_gdf['estimate_cases4_density'], 0.99)
# Out:
# nan

# %%
def drawCaseDensity(col):
    case_map = info_case_gdf.plot(
            column = col,
            cmap = 'Reds',
            edgecolor='black',
            scheme = 'percentiles',
            linewidth = 0.1,
            alpha = 0.9, 
            legend = True,

            figsize = (10,10),
                         )

    # Adjust legend location
    leg = case_map.get_legend()
    leg.set_bbox_to_anchor((0.25,0.25))

    case_map.axis('off')

# %%
drawCaseDensity('estimate_cases1_density')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/mj/yy94wkqj1x73mgydrb1dzrqm0000gn/T/ipykernel_22991/459762423.py in <module>
# ----> 1 drawCaseDensity('estimate_cases1_density')
#
# /var/folders/mj/yy94wkqj1x73mgydrb1dzrqm0000gn/T/ipykernel_22991/4063866477.py in drawCaseDensity(col)
#       1 def drawCaseDensity(col):
# ----> 2     case_map = info_case_gdf.plot(
#       3             column = col,
#       4             cmap = 'Reds',
#       5             edgecolor='black',
#
# ~/opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py in __call__(self, *args, **kwargs)
#     948         kind = kwargs.pop("kind", "geo")
#     949         if kind == "geo":
# --> 950             return plot_dataframe(data, *args, **kwargs)
#     951         if kind in self._pandas_kinds:
#     952             # Access pandas plots
#
# ~/opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     774                 labels = [c[1:-1] for c in labels]
#     775
# --> 776         values = pd.Categorical(
#     777             [np.nan] * len(values), categories=binning.bins, ordered=True
#     778         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/categorical.py in __init__(self, values, categories, ordered, dtype, fastpath, copy)
#     369     ):
#     370
# --> 371         dtype = CategoricalDtype._from_values_or_dtype(
#     372             values, categories, ordered, dtype
#     373         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/dtypes.py in _from_values_or_dtype(cls, values, categories, ordered, dtype)
#     294             # Note: This could potentially have categories=None and
#     295             # ordered=None.
# --> 296             dtype = CategoricalDtype(categories, ordered)
#     297
#     298         return cast(CategoricalDtype, dtype)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/dtypes.py in __init__(self, categories, ordered)
#     181
#     182     def __init__(self, categories=None, ordered: Ordered = False):
# --> 183         self._finalize(categories, ordered, fastpath=False)
#     184
#     185     @classmethod
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/dtypes.py in _finalize(self, categories, ordered, fastpath)
#     335
#     336         if categories is not None:
# --> 337             categories = self.validate_categories(categories, fastpath=fastpath)
#     338
#     339         self._categories = categories
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/dtypes.py in validate_categories(categories, fastpath)
#     538
#     539             if not categories.is_unique:
# --> 540                 raise ValueError("Categorical categories must be unique")
#     541
#     542         if isinstance(categories, ABCCategoricalIndex):
#
# ValueError: Categorical categories must be unique

# %%
drawCaseDensity('estimate_cases2_density')

# %%
drawCaseDensity('estimate_cases3_density')

# %%
drawCaseDensity('estimate_cases4_density')

# %%
def drawExposure(col, path):
    case_map = info_case_gdf.plot(
        column=col,
        cmap='Reds',
        edgecolor='black',
        linewidth = 0.1,
        alpha = 0.9, 
        legend = True,

        figsize = (10,10),
                     )
    exposure_map.axis('off')
    plt.savefig(path, dpi = 200)
